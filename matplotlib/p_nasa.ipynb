# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
temp = pd.read_csv('temp.csv')

# %%
temp
# Out:
#      Year  Glob  NHem  SHem  24N-90N  24S-24N  90S-24S  64N-90N  44N-64N  \
# 0    1880 -0.17 -0.29 -0.05    -0.38    -0.12    -0.02    -0.80    -0.49
# 1    1881 -0.08 -0.17  0.00    -0.34     0.11    -0.07    -0.89    -0.44
# 2    1882 -0.11 -0.21 -0.01    -0.31    -0.04     0.01    -1.38    -0.25
# 3    1883 -0.17 -0.28 -0.07    -0.36    -0.16    -0.01    -0.23    -0.55
# 4    1884 -0.29 -0.43 -0.15    -0.62    -0.14    -0.14    -1.35    -0.67
# 5    1885 -0.33 -0.43 -0.25    -0.66    -0.12    -0.28    -1.54    -0.68
# 6    1886 -0.31 -0.42 -0.20    -0.57    -0.18    -0.22    -1.61    -0.49
# 7    1887 -0.35 -0.42 -0.29    -0.52    -0.28    -0.29    -1.76    -0.50
# 8    1888 -0.17 -0.22 -0.12    -0.41     0.11    -0.29    -1.31    -0.40
# 9    1889 -0.10 -0.16 -0.05    -0.30     0.09    -0.17    -0.70    -0.21
# 10   1890 -0.35 -0.38 -0.33    -0.47    -0.35    -0.23    -1.15    -0.58
# 11   1891 -0.22 -0.24 -0.20    -0.43    -0.06    -0.22    -1.12    -0.32
# ...

# %%
plt.plot(temp.Year, temp.Glob)
plt.show()
